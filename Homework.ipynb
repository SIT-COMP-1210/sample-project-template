# %% [markdown]
# # sample-project

# %% [markdown]
# ## Submission Reminder
#
# When you're finished, save your work back to GitHub with **File → Save** (or Ctrl+S). Make sure it saves to the **`main`** branch of **[REPO_PLACEHOLDER](https://github.com/REPO_PLACEHOLDER)**.
#
# > **Note:** Colab autosaves to Google Drive, not GitHub — you must explicitly use File → Save to submit.
#
# [Click here to verify your answers are saved on GitHub (main branch)](https://github.com/REPO_PLACEHOLDER/blob/main/Homework.ipynb)

# %%
student_name  = "First Last"      # replace with your name
student_email = "abc1234@sit.edu"  # replace with your student email

# %% [markdown]
# ## How to Complete This Notebook
#
# All answers go in **code cells** (gray background). Replace the placeholder value with your answer and press **Shift+Enter** to run the cell.

# %% [markdown]
# ---
# ## Submission
#
# When you're done, save this notebook back to GitHub:
#
# **File → Save** (or Ctrl+S) — make sure it saves to the **`main`** branch of **[REPO_PLACEHOLDER](https://github.com/REPO_PLACEHOLDER)**.
#
# > **Note:** Colab autosaves to Google Drive, not GitHub. You must use File → Save to submit your work.
#
# [Click here to verify your answers are saved on GitHub (main branch)](https://github.com/REPO_PLACEHOLDER/blob/main/Homework.ipynb)
